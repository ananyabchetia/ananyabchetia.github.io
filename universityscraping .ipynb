# %%
import folium
import geopandas as gpd

# Remove rows with NaN latitude or longitude
gdf_filtered = gdfa.dropna(subset=['Latitude', 'Longitude'])

# Create the map
m = folium.Map(location=[20, 0], zoom_start=2, width='800px', height='500px')

# Add markers with smaller icons
for idx, row in gdf_filtered.iterrows():
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=f"""
        <b>University Name:</b> {row['University Name']}
        <br>
        <b>Financial Package for International Students:</b> {row['Financial Package for International Students']}
        <br>
        <b>Total Cost:</b> {row['Total Cost']}
        """,
        icon=folium.Icon(icon='university', prefix='fa', icon_size=(25, 25))  # Smaller icon size
    ).add_to(m)


# Display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_dcb969ec219a19aa699e6064d97c1c87 {
#                     position: relative;
#                     width: 800.0px;
#                     height: 500.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_dcb969ec219a19aa699e6064d97c1c87&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_dcb969ec219a19aa699e6064d97c1c87 = L.map(
#                 &quot;map_dcb969ec219a19aa699e6064d97c1c87&quot;,
#                 {
#                     center: [20.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_379504deaebb4de319aac54c7d5fcb67 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_379504deaebb4de319aac54c7d5fcb67.addTo(map_dcb969ec219a19aa699e6064d97c1c87);
#
#
#             var marker_e2bb1efa2303d0db2daf7ee4d5185169 = L.marker(
#                 [40.72164933, -73.64432612],
#                 {}
#             ).addTo(map_dcb969ec219a19aa699e6064d97c1c87);
#
#
#             var icon_b657d3a76ba927305cc03d0c32baaa1f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;university&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;iconSize&quot;: [25, 25], &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_e2bb1efa2303d0db2daf7ee4d5185169.setIcon(icon_b657d3a76ba927305cc03d0c32baaa1f);
#
#
#         var popup_837f949259f8548cac25a535620a4e3a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c2a1f18c377a58f68706a08c22182ec5 = $(`&lt;div id=&quot;html_c2a1f18c377a58f68706a08c22182ec5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;         &lt;b&gt;University Name:&lt;/b&gt; Adelphi University         &lt;br&gt;         &lt;b&gt;Financial Package for International Students:&lt;/b&gt; nan         &lt;br&gt;         &lt;b&gt;Total Cost:&lt;/b&gt; nan         &lt;/div&gt;`)[0];
#                 popup_837f949259f8548cac25a535620a4e3a.setContent(html_c2a1f18c377a58f68706a08c22182ec5);
#
#
#
#         marker_e2bb1efa2303d0db2daf7ee4d5185169.bindPopup(popup_837f949259f8548cac25a535620a4e3a)
#         ;
#
#
#
#
#             var marker_1ba9d04903729c89cd1458b315de8966 = L.marker(
#                 [41.89849465, -84.0608324],
#                 {}
#             ).addTo(map_dcb969ec219a19aa699e6064d97c1c87);
#
#
#             var icon_e51965fc37b821bfb188ff242dea87cb = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;university&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;iconSize&quot;: [25, 25], &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_1ba9d04903729c89cd1458b315de8966.setIcon(icon_e51965fc37b821bfb188ff242dea87cb);
#
#
#         var popup_f074ebcea0586076c1b1d7b3ac1a6758 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b649517bf36a1fd53fcea83587253120 = $(`&lt;div id=&quot;html_b649517bf36a1fd53fcea83587253120&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;         &lt;b&gt;University Name:&lt;/b&gt; Adrian College         &lt;br&gt;         &lt;b&gt;Financial Package for International Students:&lt;/b&gt; nan         &lt;br&gt;         &lt;b&gt;Total Cost:&lt;/b&gt; nan         &lt;/div&gt;`)[0];
#                 popup_f074ebcea0586076c1b1d7b3ac1a6758.setContent(html_b649517bf36a1fd53fcea83587253120);
#
#
#
#         marker_1ba9d04903729c89cd1458b315de8966.bindPopup(popup_f074ebcea0586076c1b1d7b3ac1a6758)
#         ;
#
#
#
#
#             var marker_ffdae61c0e25b0ae4b66716e6e75caac = L.marker(
#                 [33.7688851, -84.2944452],
#                 {}
#             ).addTo(map_dcb969ec219a19aa699e6064d97c1c87);
#
#
#             var icon_a5f8bc3f8e4edb0fb3030d861720e3d8 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;university&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;iconSize&quot;: [25, 25], &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_ffdae61c0e25b0ae4b66716e6e75caac.setIcon(icon_a5f8bc3f8e4edb0fb3030d861720e3d8);
#
#
#         var popup_acf35a8614b224e0946c3a31d0bea690 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a872322309386e54deefb2c15fef47e1 = $(`&lt;div id=&quot;html_a872322309386e54deefb2c15fef47e1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;         &lt;b&gt;University Name:&lt;/b&gt; Agnes Scott College         &lt;br&gt;         &lt;b&gt;Financial Package for International Students:&lt;/b&gt; $35,518         &lt;br&gt;         &lt;b&gt;Total Cost:&
